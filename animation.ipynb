# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('bruv.csv')

# %%
data.drop('Province/State', axis =1, inplace = True)
data.head()
# Out:
#   Country/Region       Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0    Afghanistan  33.93911  67.709953        0        0        0        0
# 1        Albania  41.15330  20.168300        0        0        0        0
# 2        Algeria  28.03390   1.659600        0        0        0        0
# 3        Andorra  42.50630   1.521800        0        0        0        0
# 4         Angola -11.20270  17.873900        0        0        0        0
#
#    1/26/20  1/27/20  1/28/20  ...  7/22/20  7/23/20  7/24/20  7/25/20  \
# 0        0        0        0  ...    35727    35928    35981    36036
# 1        0        0        0  ...     4358     4466     4570     4637
# 2        0        0        0  ...    24872    25484    26159    26764
# 3        0        0        0  ...      889      889      897      897
# 4        0        0        0  ...      812      851      880      916
#
#    7/26/20  7/27/20  7/28/20  7/29/20  7/30/20  7/31/20
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20', '1/24/20',
#        '1/25/20', '1/26/20', '1/27/20', '1/28/20',
#        ...
#        '7/22/20', '7/23/20', '7/24/20', '7/25/20', '7/26/20', '7/27/20',
#        '7/28/20', '7/29/20', '7/30/20', '7/31/20'],
#       dtype='object', length=195)

# %%
data.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    21.076624   22.829441    2.086466    2.458647    3.537594    5.390977
# std     24.904600   70.191330   27.279200   27.377862   34.083035   47.434934
# min    -51.796300 -135.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.677575  -15.277675    0.000000    0.000000    0.000000    0.000000
# 50%     22.820850   20.921188    0.000000    0.000000    0.000000    0.000000
# 75%     41.143200   77.913685    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...       7/22/20  \
# count   266.000000   266.000000   266.000000   266.000000  ...  2.660000e+02
# mean      7.962406    11.003759    20.969925    23.180451  ...  5.724988e+04
# ...

# %%
data.columns[3:]
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '7/22/20', '7/23/20', '7/24/20', '7/25/20', '7/26/20', '7/27/20',
#        '7/28/20', '7/29/20', '7/30/20', '7/31/20'],
#       dtype='object', length=192)

# %%
list_lat= []
list_long = []

for i in range(3, 193):
    for k in range(data.shape[0]):
        if(int(data.iloc[k, i]) != 0):
            list_lat.append(data.iloc[k, 1])
            list_long.append(data.iloc[k, 2])
            data.iloc[k, 1] = 500
            data.iloc[k, 2] = 500
        else:
            continue
            
list_lat[0:5] 
list_long[0:5]
# Out:
# [117.2264, 116.4142, 107.874, 117.9874, 113.4244]

# %%
data.head()
# Out:
#   Country/Region    Lat   Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0    Afghanistan  500.0  500.0        0        0        0        0        0
# 1        Albania  500.0  500.0        0        0        0        0        0
# 2        Algeria  500.0  500.0        0        0        0        0        0
# 3        Andorra  500.0  500.0        0        0        0        0        0
# 4         Angola  500.0  500.0        0        0        0        0        0
#
#    1/27/20  1/28/20  ...  7/22/20  7/23/20  7/24/20  7/25/20  7/26/20  \
# 0        0        0  ...    35727    35928    35981    36036    36157
# 1        0        0  ...     4358     4466     4570     4637     4763
# 2        0        0  ...    24872    25484    26159    26764    27357
# 3        0        0  ...      889      889      897      897      897
# 4        0        0  ...      812      851      880      916      932
#
#    7/27/20  7/28/20  7/29/20  7/30/20  7/31/20
# ...

# %%
for i in range(list_lat.count(500)):
    list_lat.remove(500)
len(list_lat)
# Out:
# 266

# %%
for i in range(list_long.count(500)):
    list_long.remove(500)
list_long
# Out:
# [117.2264,
#  116.4142,
#  107.874,
#  117.9874,
#  113.4244,
#  108.7881,
#  106.8748,
#  109.7453,
#  116.1306,
#  114.9042,
#  112.2707,
#  111.7088,
#  119.455,
#  115.7221,
#  122.6085,
#  113.55,
#  106.1655,
#  118.1498,
#  121.4491,
#  112.2922,
#  102.7103,
#  117.323,
#  101.48700000000001,
#  120.0934,
#  138.252924,
#  127.766922,
#  121.0,
#  100.992541,
#  -100.0,
#  104.2861,
#  127.7615,
#  114.2,
#  126.1923,
#  108.8701,
#  85.2401,
#  103.8333,
#  108.277199,
#  113.9448,
#  2.2137,
#  95.9956,
#  101.97576600000001,
#  84.25,
#  151.2093,
#  144.9631,
#  -85.3232,
#  104.9167,
#  10.451526,
#  80.77179699999998,
#  -127.6476,
#  153.0251,
#  25.748151,
#  53.847818000000004,
#  88.0924,
#  78.96288,
#  121.77401699999999,
#  12.56738,
#  105.31875600000001,
#  18.643501,
#  -3.4360000000000004,
#  138.6007,
#  -3.7492199999999998,
#  4.469936,
#  0.0,
#  30.802497999999996,
#  53.68804599999999,
#  34.851612,
#  35.8623,
#  -71.543,
#  67.709953,
#  50.55,
# ...

# %% [markdown]
# ## This makes a list of all the latitudes and longitudes, in the order of the COVID-19 timeline

# %% [markdown]
# ## Animation

# %%
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.pyplot as plt
import cartopy.mpl.geoaxes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ## Making the Cartopy Map

# %%
fig = plt.figure()
m1 = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
m1.add_feature(cfeature.LAND)
m1.add_feature(cfeature.OCEAN)
m1.add_feature(cfeature.COASTLINE)
m1.add_feature(cfeature.BORDERS, linestyle=':')
m1.add_feature(cfeature.LAKES, alpha=0.5)
m1.add_feature(cfeature.RIVERS)
m1.stock_img()

# %% [markdown]
# ## Making the animation

# %%
X_points_bla = list_long
Y_points_bla= list_lat

def animate(i):
    X_points= X_points_bla[0]
    Y_points= Y_points_bla[0]
    X_points_bla.remove(X_points_bla[0])
    Y_points_bla.remove(Y_points_bla[0])
    m1.scatter(X_points, Y_points, color = 'red')



ani= FuncAnimation(fig, animate, 265, interval=200, repeat = False)
plt.show()
